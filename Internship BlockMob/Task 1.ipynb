# %%
print("Block Mob lab Date",  "02 Jan",2025)
# Out:
# Block Mob lab Date 02 Jan 2025

# %%
print("Today my first day at Blockmob Lab \n i am really enjoyed today")
# Out:
# Today my first day at Blockmob Lab
#  i am really enjoyed today

# %%
print("Hello word"+ "5") #() a function
# Out:
# Hello word5

# %%
print(9*43)
# Out:
# 387

# %% [markdown]
#  #### Data Types

# %%
num =34435
flt =34.343
compls = 4j

# %%
print(type(num))
# Out:
# <class 'int'>

# %%
print(type(flt))
# Out:
# <class 'float'>

# %%
print(type(compls))
# Out:
# <class 'complex'>

# %%
print(num+flt)
# Out:
# 34469.343

# %%
print(flt+compls)
# Out:
# (34.343+4j)

# %%
print(flt-compls+num)
# Out:
# (34469.343-4j)

# %%
correct = True
empty = None

# %%
print(type(correct))
# Out:
# <class 'bool'>

# %%
print((type(empty)))
# Out:
# <class 'NoneType'>

# %%
str = "45"
number = 354
str_number = int(str)
total = str_number + number
print(total)
# Out:
# 399

# %%
a = int(input("Enter First number "))
b = int(input("Enter Second number "))
add = a+b
sub = a-b
div = a/b
remin = a%b
s =a//b
# Out:
# Enter First number 45
# Enter Second number 34

# %%
print(add)
print(sub)
print(div)
print(remin)
print(s)
# Out:
# 79
# 11
# 1.3235294117647058
# 11
# 1
